# %%
# 引入 requests
import requests 

 # 名為 r 的 Response 對象
r=requests.get('https://api.github.com/events')

# requests使用其推測的編碼，響應出內容
r.text

# %%
# 引入 requests
import requests 

 # 名為 r 的 Response 對象
r=requests.get('https://api.github.com/events')

# requests使用JSON格式，響應出內容
r.json()
# Out:
# [{'id': '8466993118',
#   'type': 'DeleteEvent',
#   'actor': {'id': 2965042,
#    'login': 'rameshvk',
#    'display_login': 'rameshvk',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/rameshvk',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/2965042?'},
#   'repo': {'id': 114581200,
#    'name': 'dotchain/dot',
#    'url': 'https://api.github.com/repos/dotchain/dot'},
#   'payload': {'ref': 'wip', 'ref_type': 'branch', 'pusher_type': 'user'},
#   'public': True,
#   'created_at': '2018-10-23T15:50:06Z',
#   'org': {'id': 34582390,
#    'login': 'dotchain',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/dotchain',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/34582390?'}},
#  {'id': '8466993116',
#   'type': 'CreateEvent',
#   'actor': {'id': 32371408,
#    'login': 'codestar-bot',
#    'display_login': 'codestar-bot',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/codestar-bot',
# ...
